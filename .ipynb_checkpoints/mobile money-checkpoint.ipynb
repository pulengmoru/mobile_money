# %%
import os
import pandas as pd
import seaborn as sns
sns.set()
import numpy as np
import matplotlib.pyplot as plt

# %%
cash_outlet = pd.read_csv('training.csv')

# %%
cash_outlet.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %%
cash_outlet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7094 entries, 0 to 7093
# Data columns (total 37 columns):
# ID                             7094 non-null int64
# Q1                             7094 non-null int64
# Q2                             7094 non-null int64
# Q3                             7094 non-null int64
# Q4                             7094 non-null int64
# Q5                             7094 non-null int64
# Q6                             7094 non-null int64
# Q7                             7094 non-null int64
# Q8_1                           7094 non-null int64
# Q8_2                           7094 non-null int64
# Q8_3                           7094 non-null int64
# Q8_4                           7094 non-null int64
# Q8_5                           7094 non-null int64
# Q8_6                           7094 non-null int64
# Q8_7                           7094 non-null int64
# Q8_8                           7094 non-null int64
# ...

# %%
cash_outlet.isnull().values.any()
# Out:
# False

# %%
cash_outlet.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %%
cash_outlet.rename(inplace=True, columns={
    'Q1':'age',
    'Q2':'gender',
    'Q3':'marital status',
    'Q4':'Highest level of education',
    'Q5':'property ownership',
    'Q6':'land ownership',
    'Q7':'personal mobile status',
    'Q8_1':'salaries or wages',
    'Q8_2':'money trading or selling',
    'Q8_3':'money providing a service',
    'Q8_4':'money casual work',
    'Q8_5':'money rental income',
    'Q8_6':'money interests',
    'Q8_7':'money pension',
    'Q8_8':'money social welfare',
    'Q8_9':'money financially dependant',
    'Q8_10':'money no income',
    'Q9':'salary and wages',
    'Q10':'selling things',
    'Q11':'providing a service',
    'Q12':'send money to another country',
    'Q13':'money last sent',
    'Q14':'received money from another country',
    'Q15':'last money received',
    'Q16':'mobile money purchases',
    'Q17':'mobile money bills',
    'Q18':'literacy in kwiswhahili',
    'Q19':'literacy in english'
    
})

# %%
cash_outlet.head()
# Out:
#      ID  age  gender  marital status  Highest level of education  \
# 0  5086   98       2               3                           1
# 1  1258   40       1               1                           3
# 2   331   18       2               4                           6
# 3  6729   50       1               1                           3
# 4  8671   34       1               1                           1
#
#    property ownership  land ownership  personal mobile status  \
# 0                   1               2                       2
# 1                   5               1                       1
# 2                   3               2                       1
# 3                   1               1                       1
# 4                   1               2                       1
#
#    salaries or wages  money trading or selling  ...  mobile money bills  \
# 0                  0                         0  ...                  -1
# ...

# %%
cash_outlet.isnull().values.any()
# Out:
# False

# %%
cash_outlet.groupby(by='gender').size()
# Out:
# gender
# 1    3122
# 2    3972
# dtype: int64

# %%
cash_outlet.gender= ['male' if each == 1 else 'female' for each in cash_outlet.gender]

# %%
cash_outlet.groupby(by='gender').size()
# Out:
# gender
# female    3972
# male      3122
# dtype: int64

# %%
cash_outlet.groupby(by='mobile_money_classification').size()
# Out:
# mobile_money_classification
# 0    1386
# 1    1778
# 2     804
# 3    3126
# dtype: int64

# %%
cash_outlet['mobile_money_classification'].replace([0,1,2,3],['None','FS_only','MM_only','MM_FS'],inplace=True)

# %%
cash_outlet.groupby(by='mobile_money_classification').size()
# Out:
# mobile_money_classification
# FS_only    1778
# MM_FS      3126
# MM_only     804
# None       1386
# dtype: int64

# %%
sns.countplot(x = 'mobile_money_classification', hue = 'gender',data = cash_outlet)
plt.legend(loc = 'best')
plt.xticks(np.arange(4), ['None', 'FS_only', 'MM_only', 'MM_FS'])
plt.show()

# %%
cash_outlet.groupby(by='age').size()
# Out:
# age
# 16     119
# 17     138
# 18     158
# 19     140
# 20     200
# 21     151
# 22     226
# 23     216
# 24     187
# 25     260
# 26     189
# 27     197
# 28     224
# 29     176
# 30     312
# 31     128
# 32     229
# 33     127
# 34     160
# 35     247
# 36     142
# 37     125
# 38     142
# 39      96
# 40     232
# 41      85
# 42     134
# 43     117
# 44      72
# 45     187
#       ...
# 71      17
# 72      31
# 73      19
# 74      17
# 75      48
# 76      21
# 77      15
# 78      23
# 79      12
# 80      41
# 81       8
# 82      18
# 83       6
# 84       3
# 85      14
# 86       5
# 87       3
# 88       7
# 89       1
# 90      12
# 91       2
# 92       1
# 93       1
# 94       2
# 95       2
# 96       1
# 97       1
# 98       3
# 99       1
# 100      5
# Length: 85, dtype: int64

# %%
bins = 5
x = cash_outlet['mobile_money_classification']
y = cash_outlet['age']
plt.hist(x, bins = 10)
plt.show()

# %%
#outlet.set_index('mobile_money_classification').T.plot(kind='bar', stacked=True)
outlet.hist()
plt.show()
